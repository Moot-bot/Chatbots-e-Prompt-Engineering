# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.37.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.31.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.10.5 in /usr/local/lib/python3.12/dist-packages (from selenium) (2025.10.5)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.37.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 78.7 MB/s eta 0:00:00
# Downloading trio-0.31.0-py3-none-any.whl (512 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.7/512.7 kB 32.2 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 selenium-4.37.0 trio-0.31.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from urllib.parse import urljoin, urlparse
import time
import json
from collections import deque
import os

def setup_driver():
    """Configurar o driver do Chrome"""
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--window-size=1920,1080")

    driver = webdriver.Chrome(options=chrome_options)
    return driver

def get_page_content(driver, url):
    """Extrair conteúdo de uma página específica"""
    try:
        driver.get(url)
        time.sleep(2)  # Esperar carregar

        # Extrair título
        title = driver.title
        if not title or title == "AnyLogic Help":
            try:
                title = driver.find_element(By.TAG_NAME, "h1").text
            except:
                title = "Sem título"

        # Extrair conteúdo principal
        content_selectors = [
            "main", ".content", "#content", ".main-content",
            ".documentation", "article", ".help-content", "body"
        ]

        content_element = None
        for selector in content_selectors:
            try:
                content_element = driver.find_element(By.CSS_SELECTOR, selector)
                break
            except:
                continue

        if content_element:
            content = content_element.text
        else:
            content = driver.find_element(By.TAG_NAME, "body").text

        # Extrair links da página (para continuar o crawling)
        links = []
        try:
            link_elements = driver.find_elements(By.CSS_SELECTOR, "a[href]")
            for link in link_elements:
                href = link.get_attribute("href")
                if href and "anylogic.help" in href:
                    links.append(href)
        except:
            pass

        return {
            "url": url,
            "title": title,
            "content": content,
            "links": links
        }

    except Exception as e:
        print(f"❌ Erro ao acessar {url}: {e}")
        return None

def crawl_anylogic_docs(start_url, max_pages=100):
    """Crawler para navegar por toda a documentação"""
    driver = setup_driver()

    try:
        # Estruturas para controle do crawling
        visited = set()
        to_visit = deque([start_url])
        all_pages = []

        print(f"🚀 Iniciando crawling a partir de: {start_url}")
        print(f"📝 Limite máximo de páginas: {max_pages}")

        while to_visit and len(visited) < max_pages:
            current_url = to_visit.popleft()

            if current_url in visited:
                continue

            print(f"📖 Processando página {len(visited) + 1}: {current_url}")

            # Extrair conteúdo da página atual
            page_data = get_page_content(driver, current_url)

            if page_data:
                visited.add(current_url)
                all_pages.append(page_data)

                # Adicionar novos links para visitar
                for link in page_data["links"]:
                    if link not in visited and link not in to_visit:
                        # Filtrar apenas links relevantes da documentação
                        if any(pattern in link for pattern in [
                            "/anylogic/",
                            "anylogic.help/anylogic",
                            "index.html"
                        ]):
                            to_visit.append(link)

                print(f"✅ Página salva: {page_data['title']}")
                print(f"   📊 Links encontrados: {len(page_data['links'])}")
                print(f"   📏 Conteúdo: {len(page_data['content'])} caracteres")

            # Pequena pausa para não sobrecarregar o servidor
            time.sleep(1)

        print(f"\n🎯 Crawling completo! {len(all_pages)} páginas processadas.")
        return all_pages

    finally:
        driver.quit()

def save_documentation(pages, output_dir="anylogic_documentation"):
    """Salvar a documentação extraída em arquivos organizados"""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Salvar cada página individualmente
    for i, page in enumerate(pages):
        filename = f"page_{i+1:03d}.txt"
        filepath = os.path.join(output_dir, filename)

        with open(filepath, "w", encoding="utf-8") as f:
            f.write(f"URL: {page['url']}\n")
            f.write(f"Título: {page['title']}\n")
            f.write("=" * 80 + "\n")
            f.write(page['content'])
            f.write("\n" + "=" * 80 + "\n")
            f.write(f"Links encontrados: {len(page['links'])}\n")

    # Salvar índice geral
    index_path = os.path.join(output_dir, "index.json")
    index_data = []

    for i, page in enumerate(pages):
        index_data.append({
            "id": i + 1,
            "title": page["title"],
            "url": page["url"],
            "content_length": len(page["content"]),
            "links_count": len(page["links"]),
            "filename": f"page_{i+1:03d}.txt"
        })

    with open(index_path, "w", encoding="utf-8") as f:
        json.dump(index_data, f, indent=2, ensure_ascii=False)

    # Salvar um arquivo consolidado
    consolidated_path = os.path.join(output_dir, "consolidated_documentation.txt")
    with open(consolidated_path, "w", encoding="utf-8") as f:
        f.write("DOCUMENTAÇÃO COMPLETA ANYLOGIC\n")
        f.write("=" * 50 + "\n\n")

        for i, page in enumerate(pages):
            f.write(f"CAPÍTULO {i+1}: {page['title']}\n")
            f.write(f"URL: {page['url']}\n")
            f.write("-" * 50 + "\n")
            f.write(page['content'])
            f.write("\n\n" + "=" * 80 + "\n\n")

    return len(pages)

# EXECUÇÃO PRINCIPAL
if __name__ == "__main__":
    start_url = "https://anylogic.help/anylogic/index.html"

    print("🌐 INICIANDO CRAWLER DA DOCUMENTAÇÃO ANYLOGIC")
    print("=" * 60)

    # Fazer o crawling de todas as páginas
    all_pages = crawl_anylogic_docs(start_url, max_pages=50)

    if all_pages:
        # Salvar os resultados
        pages_saved = save_documentation(all_pages)

        print(f"\n💾 DOCUMENTAÇÃO SALVA COM SUCESSO!")
        print(f"📁 Pasta: anylogic_documentation/")
        print(f"📄 Total de páginas: {pages_saved}")
        print(f"📊 Arquivos gerados:")
        print(f"   - page_001.txt a page_{pages_saved:03d}.txt (páginas individuais)")
        print(f"   - index.json (índice da documentação)")
        print(f"   - consolidated_documentation.txt (arquivo consolidado)")

        # Mostrar estatísticas
        total_content = sum(len(page['content']) for page in all_pages)
        total_links = sum(len(page['links']) for page in all_pages)

        print(f"\n📈 ESTATÍSTICAS:")
        print(f"   📏 Total de caracteres: {total_content:,}")
        print(f"   🔗 Total de links encontrados: {total_links}")
        print(f"   📚 Média de conteúdo por página: {total_content//len(all_pages):,} caracteres")

    else:
        print("❌ Nenhuma página foi processada!")
# Out:
# 🌐 INICIANDO CRAWLER DA DOCUMENTAÇÃO ANYLOGIC
# ============================================================
# 🚀 Iniciando crawling a partir de: https://anylogic.help/anylogic/index.html
# 📝 Limite máximo de páginas: 50
# 📖 Processando página 1: https://anylogic.help/anylogic/index.html
# ✅ Página salva: AnyLogic Help | AnyLogic Help
#    📊 Links encontrados: 957
#    📏 Conteúdo: 587 caracteres
# 📖 Processando página 2: https://anylogic.help/anylogic/introduction/index.html
# ✅ Página salva: Introduction | AnyLogic Help
#    📊 Links encontrados: 952
#    📏 Conteúdo: 687 caracteres
# 📖 Processando página 3: https://anylogic.help/anylogic/introduction/activation-index.html
# ✅ Página salva: AnyLogic activation | AnyLogic Help
#    📊 Links encontrados: 948
#    📏 Conteúdo: 787 caracteres
# 📖 Processando página 4: https://anylogic.help/anylogic/introduction/activation-with-permanent-key.html
# ✅ Página salva: Activating AnyLogic with the key | AnyLogic Help
#    📊 Links encontrados: 955
#    📏 Conteúdo: 5565 caracteres
# 📖 Processando página 5: https://anylogic.help/anylogic/introduction/activating-dongle.html
# ✅ Página salva: Activating AnyLogic with USB dongle | AnyLogic Help
#    📊 Links encontrados: 953
#    📏 Conteúdo: 3600 caracteres
# 📖 Processando página 6: https://anylogic.help/anylogic/introduction/activation-tls.html
# ✅ Página salva: Activating AnyLogic with Team License Server | AnyLogic Help
#    📊 Links encontrados: 954
#    📏 Conteúdo: 2733 caracteres
# 📖 Processando página 7: https://anylogic.help/license-server/index.html
# ✅ Página salva: Team License Server | Team License Server Help
#    📊 Links encontrados: 18
#    📏 Conteúdo: 2288 caracteres
# 📖 Processando página 8: https://anylogic.help/anylogic/ui/editions.html
# ✅ Página salva: AnyLogic editions comparison | AnyLogic Help
#    📊 Links encontrados: 990
#    📏 Conteúdo: 3837 caracteres
# 📖 Processando página 9: https://anylogic.help/anylogic/introduction/anylogic-professional.html
# ✅ Página salva: AnyLogic Professional | AnyLogic Help
#    📊 Links encontrados: 961
#    📏 Conteúdo: 5249 caracteres
# 📖 Processando página 10: https://anylogic.help/anylogic/ui/support-services.html
# ✅ Página salva: AnyLogic support services | AnyLogic Help
#    📊 Links encontrados: 977
#    📏 Conteúdo: 7967 caracteres
# 📖 Processando página 11: https://anylogic.help/anylogic/ui/system-requirements.html
# ✅ Página salva: System requirements | AnyLogic Help
#    📊 Links encontrados: 956
#    📏 Conteúdo: 2603 caracteres
# 📖 Processando página 12: https://anylogic.help/anylogic/introduction/release-notes.html
# ✅ Página salva: Release notes | AnyLogic Help
#    📊 Links encontrados: 1398
#    📏 Conteúdo: 145247 caracteres
# 📖 Processando página 13: https://anylogic.help/anylogic/introduction/style-conventions.html
# ✅ Página salva: Style conventions | AnyLogic Help
#    📊 Links encontrados: 962
#    📏 Conteúdo: 3748 caracteres
# 📖 Processando página 14: https://anylogic.help/anylogic/introduction/demo-models.html
# ✅ Página salva: Demo models | AnyLogic Help
#    📊 Links encontrados: 951
#    📏 Conteúdo: 2336 caracteres
# 📖 Processando página 15: https://anylogic.help/anylogic/ui/concepts-index.html
# ✅ Página salva: Basic concepts | AnyLogic Help
#    📊 Links encontrados: 946
#    📏 Conteúdo: 419 caracteres
# 📖 Processando página 16: https://anylogic.help/anylogic/ui/models.html
# ✅ Página salva: Models | AnyLogic Help
#    📊 Links encontrados: 961
#    📏 Conteúdo: 1164 caracteres
# 📖 Processando página 17: https://anylogic.help/anylogic/ui/creating-a-new-model.html
# ✅ Página salva: Creating a new model | AnyLogic Help
#    📊 Links encontrados: 965
#    📏 Conteúdo: 2155 caracteres
# 📖 Processando página 18: https://anylogic.help/anylogic/ui/opening-a-model.html
# ✅ Página salva: Opening a model | AnyLogic Help
#    📊 Links encontrados: 958
#    📏 Conteúdo: 2187 caracteres
# 📖 Processando página 19: https://anylogic.help/anylogic/ui/saving-models.html
# ✅ Página salva: Saving models | AnyLogic Help
#    📊 Links encontrados: 958
#    📏 Conteúdo: 1396 caracteres
# 📖 Processando página 20: https://anylogic.help/anylogic/ui/autosave.html
# ✅ Página salva: Automatic backup and recovery of models | AnyLogic Help
#    📊 Links encontrados: 948
#    📏 Conteúdo: 2668 caracteres
# 📖 Processando página 21: https://anylogic.help/anylogic/ui/closing-a-model.html
# ✅ Página salva: Closing models | AnyLogic Help
#    📊 Links encontrados: 956
#    📏 Conteúdo: 1633 caracteres
# 📖 Processando página 22: https://anylogic.help/anylogic/ui/model-formats.html
# ✅ Página salva: Model file formats | AnyLogic Help
#    📊 Links encontrados: 965
#    📏 Conteúdo: 3121 caracteres
# 📖 Processando página 23: https://anylogic.help/anylogic/ui/refactoring.html
# ✅ Página salva: Renaming model elements | AnyLogic Help
#    📊 Links encontrados: 953
#    📏 Conteúdo: 2948 caracteres
# 📖 Processando página 24: https://anylogic.help/anylogic/ui/managing-a-model.html
# ✅ Página salva: Managing model elements | AnyLogic Help
#    📊 Links encontrados: 948
#    📏 Conteúdo: 1793 caracteres
# 📖 Processando página 25: https://anylogic.help/anylogic/connectivity/resources.html
# ✅ Página salva: File resources | AnyLogic Help
#    📊 Links encontrados: 980
#    📏 Conteúdo: 4174 caracteres
# 📖 Processando página 26: https://anylogic.help/anylogic/ui/documenting-a-model.html
# ✅ Página salva: Documenting a model | AnyLogic Help
#    📊 Links encontrados: 952
#    📏 Conteúdo: 2703 caracteres
# 📖 Processando página 27: https://anylogic.help/anylogic/ui/approaches-index.html
# ✅ Página salva: Modeling approaches | AnyLogic Help
#    📊 Links encontrados: 951
#    📏 Conteúdo: 693 caracteres
# 📖 Processando página 28: https://anylogic.help/anylogic/statecharts/discrete-event-modeling-concept.html
# ✅ Página salva: Discrete Event modeling | AnyLogic Help
#    📊 Links encontrados: 955
#    📏 Conteúdo: 3047 caracteres
# 📖 Processando página 29: https://anylogic.help/anylogic/ui/sd.html
# ✅ Página salva: System Dynamics modeling | AnyLogic Help
#    📊 Links encontrados: 957
#    📏 Conteúdo: 4397 caracteres
# 📖 Processando página 30: https://anylogic.help/anylogic/ui/agent-based-modeling.html
# ✅ Página salva: Agent Based modeling | AnyLogic Help
#    📊 Links encontrados: 959
#    📏 Conteúdo: 9683 caracteres
# 📖 Processando página 31: https://anylogic.help/anylogic/ui/dynamic-systems.html
# ✅ Página salva: Dynamic Systems modeling | AnyLogic Help
#    📊 Links encontrados: 957
#    📏 Conteúdo: 3340 caracteres
# 📖 Processando página 32: https://anylogic.help/anylogic/ui/multimethod.html
# ✅ Página salva: Multimethod modeling | AnyLogic Help
#    📊 Links encontrados: 956
#    📏 Conteúdo: 3551 caracteres
# 📖 Processando página 33: https://anylogic.help/anylogic/multimethod/index.html
# ✅ Página salva: Combining modeling methods | AnyLogic Help
#    📊 Links encontrados: 964
#    📏 Conteúdo: 14654 caracteres
# 📖 Processando página 34: https://anylogic.help/anylogic/ui/index.html
# ✅ Página salva: AnyLogic user interface | AnyLogic Help
#    📊 Links encontrados: 966
#    📏 Conteúdo: 1113 caracteres
# 📖 Processando página 35: https://anylogic.help/anylogic/ui/workspace.html
# ✅ Página salva: AnyLogic UI | AnyLogic Help
#    📊 Links encontrados: 963
#    📏 Conteúdo: 1944 caracteres
# 📖 Processando página 36: https://anylogic.help/anylogic/ui/welcome-page.html
# ✅ Página salva: Welcome page | AnyLogic Help
#    📊 Links encontrados: 948
#    📏 Conteúdo: 1644 caracteres
# 📖 Processando página 37: https://anylogic.help/anylogic/ui/editor-index.html
# ✅ Página salva: Graphical editor | AnyLogic Help
#    📊 Links encontrados: 954
#    📏 Conteúdo: 1213 caracteres
# 📖 Processando página 38: https://anylogic.help/anylogic/ui/graphical-editor.html
# ✅ Página salva: Graphical editor | AnyLogic Help
#    📊 Links encontrados: 956
#    📏 Conteúdo: 1781 caracteres
# 📖 Processando página 39: https://anylogic.help/anylogic/ui/ge-axis.html
# ✅ Página salva: Visible area and coordinates | AnyLogic Help
#    📊 Links encontrados: 960
#    📏 Conteúdo: 3033 caracteres
# 📖 Processando página 40: https://anylogic.help/anylogic/ui/ge-frame.html
# ✅ Página salva: Frame | AnyLogic Help
#    📊 Links encontrados: 960
#    📏 Conteúdo: 2149 caracteres
# 📖 Processando página 41: https://anylogic.help/anylogic/ui/ge-grid.html
# ✅ Página salva: Diagram grid | AnyLogic Help
#    📊 Links encontrados: 954
#    📏 Conteúdo: 2435 caracteres
# 📖 Processando página 42: https://anylogic.help/anylogic/ui/working-with-shapes-and-elements.html
# ✅ Página salva: Working with shapes and elements | AnyLogic Help
#    📊 Links encontrados: 958
#    📏 Conteúdo: 6056 caracteres
# 📖 Processando página 43: https://anylogic.help/anylogic/ui/zooming-the-diagram.html
# ✅ Página salva: Moving and zooming the diagram UI | AnyLogic Help
#    📊 Links encontrados: 952
#    📏 Conteúdo: 2300 caracteres
# 📖 Processando página 44: https://anylogic.help/anylogic/ui/ge-layers.html
# ✅ Página salva: Layers | AnyLogic Help
#    📊 Links encontrados: 952
#    📏 Conteúdo: 2419 caracteres
# 📖 Processando página 45: https://anylogic.help/anylogic/ui/ge-keyboard-shortcuts.html
# ✅ Página salva: Graphical editor: hotkeys and mouse shortcuts | AnyLogic Help
#    📊 Links encontrados: 956
#    📏 Conteúdo: 2831 caracteres
# 📖 Processando página 46: https://anylogic.help/anylogic/ui/ge-clone.html
# ✅ Página salva: Simultaneous work with several diagrams | AnyLogic Help
#    📊 Links encontrados: 952
#    📏 Conteúdo: 2967 caracteres
# 📖 Processando página 47: https://anylogic.help/anylogic/ui/projects-view.html
# ✅ Página salva: Projects view | AnyLogic Help
#    📊 Links encontrados: 962
#    📏 Conteúdo: 5666 caracteres
# 📖 Processando página 48: https://anylogic.help/anylogic/ui/palette-view.html
# ✅ Página salva: Palette view | AnyLogic Help
#    📊 Links encontrados: 962
#    📏 Conteúdo: 8940 caracteres
# 📖 Processando página 49: https://anylogic.help/anylogic/ui/anylogic-palettes.html
# ✅ Página salva: AnyLogic palettes | AnyLogic Help
#    📊 Links encontrados: 1104
#    📏 Conteúdo: 6618 caracteres
# 📖 Processando página 50: https://anylogic.help/anylogic/ui/properties-view.html
# ✅ Página salva: Properties view | AnyLogic Help
#    📊 Links encontrados: 960
#    📏 Conteúdo: 3043 caracteres
#
# 🎯 Crawling completo! 50 páginas processadas.
#
# 💾 DOCUMENTAÇÃO SALVA COM SUCESSO!
# 📁 Pasta: anylogic_documentation/
# 📄 Total de páginas: 50
# 📊 Arquivos gerados:
#    - page_001.txt a page_050.txt (páginas individuais)
#    - index.json (índice da documentação)
#    - consolidated_documentation.txt (arquivo consolidado)
#
# 📈 ESTATÍSTICAS:
#    📏 Total de caracteres: 309,112
#    🔗 Total de links encontrados: 47540
#    📚 Média de conteúdo por página: 6,182 caracteres

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from urllib.parse import urljoin, urlparse
import time
import json
from collections import deque
import os
import re

def setup_driver():
    """Configurar o driver do Chrome"""
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--window-size=1920,1080")

    driver = webdriver.Chrome(options=chrome_options)
    return driver

def clean_content(text):
    """Limpar e formatar o conteúdo extraído"""
    # Remover linhas em branco excessivas
    lines = [line.strip() for line in text.split('\n') if line.strip()]

    # Juntar linhas relacionadas
    cleaned_lines = []
    for line in lines:
        if cleaned_lines and len(line) < 100 and not line.endswith(('.', ':', ';')):
            # Se a linha é curta e não termina com pontuação, pode ser continuação
            cleaned_lines[-1] += " " + line
        else:
            cleaned_lines.append(line)

    return '\n'.join(cleaned_lines)

def get_page_content(driver, url):
    """Extrair conteúdo de uma página específica"""
    try:
        driver.get(url)
        time.sleep(2)  # Esperar carregar

        # Extrair título
        title = driver.title
        if not title or title == "AnyLogic Help":
            try:
                title = driver.find_element(By.TAG_NAME, "h1").text
            except:
                try:
                    title = driver.find_element(By.CSS_SELECTOR, ".title, .page-title").text
                except:
                    title = "Sem título"

        # Extrair conteúdo principal
        content_selectors = [
            "main", ".content", "#content", ".main-content",
            ".documentation", "article", ".help-content", "body"
        ]

        content_element = None
        for selector in content_selectors:
            try:
                content_element = driver.find_element(By.CSS_SELECTOR, selector)
                break
            except:
                continue

        if content_element:
            content = content_element.text
        else:
            content = driver.find_element(By.TAG_NAME, "body").text

        # Limpar conteúdo
        content = clean_content(content)

        # Extrair links da página (para continuar o crawling)
        links = []
        try:
            link_elements = driver.find_elements(By.CSS_SELECTOR, "a[href]")
            for link in link_elements:
                href = link.get_attribute("href")
                if href and "anylogic.help/anylogic" in href:
                    # Normalizar URL
                    if "#" in href:
                        href = href.split("#")[0]  # Remover âncoras
                    links.append(href)
        except:
            pass

        return {
            "url": url,
            "title": title,
            "content": content,
            "links": list(set(links))  # Remover duplicatas
        }

    except Exception as e:
        print(f"❌ Erro ao acessar {url}: {e}")
        return None

def crawl_anylogic_docs(start_url):
    """Crawler para navegar por TODA a documentação sem limites"""
    driver = setup_driver()

    try:
        # Estruturas para controle do crawling
        visited = set()
        to_visit = deque([start_url])
        all_pages = []

        print(f"🚀 Iniciando crawling a partir de: {start_url}")
        print("📝 SEM LIMITE DE PÁGINAS - Coletando toda a documentação...")

        while to_visit:
            current_url = to_visit.popleft()

            if current_url in visited:
                continue

            print(f"📖 Processando página {len(visited) + 1}: {current_url}")

            # Extrair conteúdo da página atual
            page_data = get_page_content(driver, current_url)

            if page_data:
                visited.add(current_url)
                all_pages.append(page_data)

                # Adicionar novos links para visitar
                new_links_count = 0
                for link in page_data["links"]:
                    if link not in visited and link not in to_visit:
                        # Filtrar apenas links relevantes da documentação
                        if any(pattern in link for pattern in [
                            "/anylogic/",
                            "anylogic.help/anylogic",
                            "index.html"
                        ]) and not any(exclude in link for exclude in [
                            "javascript:", "mailto:", ".pdf", ".zip"
                        ]):
                            to_visit.append(link)
                            new_links_count += 1

                print(f"✅ Página {len(visited)}: {page_data['title'][:50]}...")
                print(f"   📊 Links encontrados: {len(page_data['links'])} | Novos: {new_links_count}")
                print(f"   📏 Conteúdo: {len(page_data['content'])} caracteres")
                print(f"   📚 Fila: {len(to_visit)} páginas restantes")

            # Pequena pausa para não sobrecarregar o servidor
            time.sleep(1)

        print(f"\n🎯 Crawling completo! {len(all_pages)} páginas processadas.")
        return all_pages

    finally:
        driver.quit()

def create_consolidated_documentation(pages, output_file="anylogic_documentacao_completa.txt"):
    """Criar um arquivo único consolidado com toda a documentação"""

    print(f"📄 Criando arquivo consolidado: {output_file}")

    with open(output_file, "w", encoding="utf-8") as f:
        # Cabeçalho
        f.write("=" * 80 + "\n")
        f.write("DOCUMENTAÇÃO COMPLETA ANYLOGIC\n")
        f.write("=" * 80 + "\n")
        f.write(f"Total de páginas: {len(pages)}\n")
        f.write(f"Data de extração: {time.strftime('%d/%m/%Y %H:%M:%S')}\n")
        f.write("=" * 80 + "\n\n")

        # Conteúdo de cada página
        for i, page in enumerate(pages, 1):
            f.write(f"{'=' * 80}\n")
            f.write(f"CAPÍTULO {i:03d}: {page['title']}\n")
            f.write(f"URL: {page['url']}\n")
            f.write(f"{'=' * 80}\n\n")
            f.write(page['content'])
            f.write("\n\n")

            # Progresso
            if i % 10 == 0:
                print(f"📝 Escrita: {i}/{len(pages)} páginas...")

    print(f"✅ Arquivo consolidado criado: {output_file}")
    return output_file

def save_individual_pages(pages, output_dir="anylogic_pages"):
    """Salvar páginas individuais (opcional)"""
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for i, page in enumerate(pages, 1):
        filename = f"pagina_{i:03d}_{re.sub(r'[^a-zA-Z0-9]', '_', page['title'][:30])}.txt"
        filepath = os.path.join(output_dir, filename)

        with open(filepath, "w", encoding="utf-8") as f:
            f.write(f"URL: {page['url']}\n")
            f.write(f"Título: {page['title']}\n")
            f.write("=" * 80 + "\n")
            f.write(page['content'])

    print(f"✅ {len(pages)} páginas individuais salvas em '{output_dir}/'")

def generate_statistics(pages):
    """Gerar estatísticas da documentação"""
    total_chars = sum(len(page['content']) for page in pages)
    total_words = sum(len(page['content'].split()) for page in pages)

    print("\n📊 ESTATÍSTICAS DA DOCUMENTAÇÃO:")
    print(f"   📚 Total de páginas: {len(pages)}")
    print(f"   📏 Total de caracteres: {total_chars:,}")
    print(f"   🔤 Total de palavras: {total_words:,}")
    print(f"   📄 Média por página: {total_chars//len(pages):,} caracteres")
    print(f"   🌐 URLs únicas coletadas: {len(set(page['url'] for page in pages))}")

    # Top 10 páginas com mais conteúdo
    sorted_pages = sorted(pages, key=lambda x: len(x['content']), reverse=True)[:10]
    print(f"\n🏆 TOP 10 PÁGINAS COM MAIS CONTEÚDO:")
    for i, page in enumerate(sorted_pages, 1):
        print(f"   {i:2d}. {page['title'][:50]}... ({len(page['content']):,} chars)")

# EXECUÇÃO PRINCIPAL
if __name__ == "__main__":
    start_url = "https://anylogic.help/anylogic/index.html"

    print("🌐 INICIANDO CRAWLER COMPLETO DA DOCUMENTAÇÃO ANYLOGIC")
    print("=" * 60)
    print("⚡ SEM LIMITES - Coletando TODA a documentação disponível")
    print("💾 Será criado um único arquivo consolidado com todo o conteúdo")
    print("=" * 60)

    # Fazer o crawling de TODAS as páginas
    start_time = time.time()
    all_pages = crawl_anylogic_docs(start_url)
    crawling_time = time.time() - start_time

    if all_pages:
        # Criar arquivo consolidado único
        consolidated_file = create_consolidated_documentation(all_pages)

        # (Opcional) Salvar páginas individuais também
        save_individual_pages(all_pages)

        # Gerar estatísticas
        generate_statistics(all_pages)

        print(f"\n💾 DOCUMENTAÇÃO SALVA COM SUCESSO!")
        print(f"📁 Arquivo principal: {consolidated_file}")
        print(f"⏱️  Tempo total: {crawling_time:.2f} segundos")
        print(f"📦 Tamanho aproximado: {os.path.getsize(consolidated_file) / 1024 / 1024:.2f} MB")

    else:
        print("❌ Nenhuma página foi processada!")
# Out:
# 🌐 INICIANDO CRAWLER COMPLETO DA DOCUMENTAÇÃO ANYLOGIC
# ============================================================
# ⚡ SEM LIMITES - Coletando TODA a documentação disponível
# 💾 Será criado um único arquivo consolidado com todo o conteúdo
# ============================================================
# 🚀 Iniciando crawling a partir de: https://anylogic.help/anylogic/index.html
# 📝 SEM LIMITE DE PÁGINAS - Coletando toda a documentação...
# 📖 Processando página 1: https://anylogic.help/anylogic/index.html
# ✅ Página 1: AnyLogic Help | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 331
#    📏 Conteúdo: 587 caracteres
#    📚 Fila: 331 páginas restantes
# 📖 Processando página 2: https://anylogic.help/anylogic/agentbased/agent-api.html
# ✅ Página 2: Agent API | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1561 caracteres
#    📚 Fila: 330 páginas restantes
# 📖 Processando página 3: https://anylogic.help/anylogic/ui/ge-keyboard-shortcuts.html
# ✅ Página 3: Graphical editor: hotkeys and mouse shortcuts | An...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2831 caracteres
#    📚 Fila: 329 páginas restantes
# 📖 Processando página 4: https://anylogic.help/anylogic/presentation/viewarea.html
# ✅ Página 4: View area | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6842 caracteres
#    📚 Fila: 328 páginas restantes
# 📖 Processando página 5: https://anylogic.help/anylogic/ui/welcome-page.html
# ✅ Página 5: Welcome page | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1644 caracteres
#    📚 Fila: 327 páginas restantes
# 📖 Processando página 6: https://anylogic.help/anylogic/connectivity/select-cases.html
# ✅ Página 6: Reading data from AnyLogic DB. Use cases | AnyLogi...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5536 caracteres
#    📚 Fila: 326 páginas restantes
# 📖 Processando página 7: https://anylogic.help/anylogic/3d/omniverse.html
# ✅ Página 7: Omniverse connector | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2578 caracteres
#    📚 Fila: 325 páginas restantes
# 📖 Processando página 8: https://anylogic.help/anylogic/system-dynamics/delayinformation.html
# ✅ Página 8: delayInformation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1874 caracteres
#    📚 Fila: 324 páginas restantes
# 📖 Processando página 9: https://anylogic.help/anylogic/presentation/ipresentation.html
# ✅ Página 9: Accessing the presentation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1607 caracteres
#    📚 Fila: 323 páginas restantes
# 📖 Processando página 10: https://anylogic.help/anylogic/ui/workspace.html
# ✅ Página 10: AnyLogic UI | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1944 caracteres
#    📚 Fila: 322 páginas restantes
# 📖 Processando página 11: https://anylogic.help/anylogic/statecharts/statecharts.html
# ✅ Página 11: Statecharts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2626 caracteres
#    📚 Fila: 321 páginas restantes
# 📖 Processando página 12: https://anylogic.help/anylogic/ui/graphical-editor.html
# ✅ Página 12: Graphical editor | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1781 caracteres
#    📚 Fila: 320 páginas restantes
# 📖 Processando página 13: https://anylogic.help/anylogic/gis/gis-map.html
# ✅ Página 13: GIS map | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 13690 caracteres
#    📚 Fila: 319 páginas restantes
# 📖 Processando página 14: https://anylogic.help/anylogic/agentbased/space.html
# ✅ Página 14: Space in agent-based models | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1395 caracteres
#    📚 Fila: 318 páginas restantes
# 📖 Processando página 15: https://anylogic.help/anylogic/system-dynamics/smooth.html
# ✅ Página 15: smooth | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1674 caracteres
#    📚 Fila: 317 páginas restantes
# 📖 Processando página 16: https://anylogic.help/anylogic/3d/view3d.html
# ✅ Página 16: 3D window | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4250 caracteres
#    📚 Fila: 316 páginas restantes
# 📖 Processando página 17: https://anylogic.help/anylogic/gis/gis-flowcharts.html
# ✅ Página 17: GIS agents in flowcharts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4014 caracteres
#    📚 Fila: 315 páginas restantes
# 📖 Processando página 18: https://anylogic.help/anylogic/data/exceptions.html
# ✅ Página 18: Exceptions | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5780 caracteres
#    📚 Fila: 314 páginas restantes
# 📖 Processando página 19: https://anylogic.help/anylogic/ui/agent-based-modeling.html
# ✅ Página 19: Agent Based modeling | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 9683 caracteres
#    📚 Fila: 313 páginas restantes
# 📖 Processando página 20: https://anylogic.help/anylogic/stochastic/random-number-generator.html
# ✅ Página 20: Random number generator | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4954 caracteres
#    📚 Fila: 312 páginas restantes
# 📖 Processando página 21: https://anylogic.help/anylogic/system-dynamics/system-dynamics-functions.html
# ✅ Página 21: System dynamics functions | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 927 caracteres
#    📚 Fila: 311 páginas restantes
# 📖 Processando página 22: https://anylogic.help/anylogic/agentbased/continuous-space.html
# ✅ Página 22: Continuous space | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 7028 caracteres
#    📚 Fila: 310 páginas restantes
# 📖 Processando página 23: https://anylogic.help/anylogic/ui/documenting-a-model.html
# ✅ Página 23: Documenting a model | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2703 caracteres
#    📚 Fila: 309 páginas restantes
# 📖 Processando página 24: https://anylogic.help/anylogic/ui/ge-frame.html
# ✅ Página 24: Frame | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2149 caracteres
#    📚 Fila: 308 páginas restantes
# 📖 Processando página 25: https://anylogic.help/anylogic/data/schedule-database.html
# ✅ Página 25: Loading schedule from DB | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6672 caracteres
#    📚 Fila: 307 páginas restantes
# 📖 Processando página 26: https://anylogic.help/anylogic/system-dynamics/pulsetrain.html
# ✅ Página 26: pulseTrain | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1483 caracteres
#    📚 Fila: 306 páginas restantes
# 📖 Processando página 27: https://anylogic.help/anylogic/agentbased/gis-space.html
# ✅ Página 27: GIS space | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1589 caracteres
#    📚 Fila: 305 páginas restantes
# 📖 Processando página 28: https://anylogic.help/anylogic/system-dynamics/variables-connection.html
# ✅ Página 28: Connecting SD variables | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3330 caracteres
#    📚 Fila: 304 páginas restantes
# 📖 Processando página 29: https://anylogic.help/anylogic/ui/ge-grid.html
# ✅ Página 29: Diagram grid | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2435 caracteres
#    📚 Fila: 303 páginas restantes
# 📖 Processando página 30: https://anylogic.help/anylogic/3d/camera3d.html
# ✅ Página 30: Camera | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4768 caracteres
#    📚 Fila: 302 páginas restantes
# 📖 Processando página 31: https://anylogic.help/anylogic/connectivity/block-value-db.html
# ✅ Página 31: Reading parameter value from DB | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4632 caracteres
#    📚 Fila: 301 páginas restantes
# 📖 Processando página 32: https://anylogic.help/anylogic/connectivity/excel-file.html
# ✅ Página 32: Excel file | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6718 caracteres
#    📚 Fila: 300 páginas restantes
# 📖 Processando página 33: https://anylogic.help/anylogic/system-dynamics/stock.html
# ✅ Página 33: Stock | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 8348 caracteres
#    📚 Fila: 299 páginas restantes
# 📖 Processando página 34: https://anylogic.help/anylogic/ui/properties-view.html
# ✅ Página 34: Properties view | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3043 caracteres
#    📚 Fila: 298 páginas restantes
# 📖 Processando página 35: https://anylogic.help/anylogic/experiments/parameter-variation.html
# ✅ Página 35: Parameter variation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 8964 caracteres
#    📚 Fila: 297 páginas restantes
# 📖 Processando página 36: https://anylogic.help/anylogic/data/collection-index.html
# ✅ Página 36: Collections | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 961 caracteres
#    📚 Fila: 296 páginas restantes
# 📖 Processando página 37: https://anylogic.help/anylogic/analysis/time-window.html
# ✅ Página 37: Time window | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1445 caracteres
#    📚 Fila: 295 páginas restantes
# 📖 Processando página 38: https://anylogic.help/anylogic/data/parameters-and-variables.html
# ✅ Página 38: Parameters vs. variables: what to use? | AnyLogic ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5234 caracteres
#    📚 Fila: 294 páginas restantes
# 📖 Processando página 39: https://anylogic.help/anylogic/statecharts/final-state.html
# ✅ Página 39: Final state | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1508 caracteres
#    📚 Fila: 293 páginas restantes
# 📖 Processando página 40: https://anylogic.help/anylogic/system-dynamics/dimensions.html
# ✅ Página 40: Dimensions | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3778 caracteres
#    📚 Fila: 292 páginas restantes
# 📖 Processando página 41: https://anylogic.help/anylogic/system-dynamics/dynamic-variable.html
# ✅ Página 41: Dynamic variable | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4172 caracteres
#    📚 Fila: 291 páginas restantes
# 📖 Processando página 42: https://anylogic.help/anylogic/analysis/updating-charts.html
# ✅ Página 42: Updating charts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2667 caracteres
#    📚 Fila: 290 páginas restantes
# 📖 Processando página 43: https://anylogic.help/anylogic/data/modifying.html
# ✅ Página 43: Modifying variables and parameters at runtime | An...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6635 caracteres
#    📚 Fila: 289 páginas restantes
# 📖 Processando página 44: https://anylogic.help/anylogic/system-dynamics/forecast.html
# ✅ Página 44: forecast | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1330 caracteres
#    📚 Fila: 288 páginas restantes
# 📖 Processando página 45: https://anylogic.help/anylogic/statecharts/discrete-event-modeling-concept.html
# ✅ Página 45: Discrete Event modeling | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3047 caracteres
#    📚 Fila: 287 páginas restantes
# 📖 Processando página 46: https://anylogic.help/anylogic/connectivity/execute-functions.html
# ✅ Página 46: Executing functions from the database | AnyLogic H...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4404 caracteres
#    📚 Fila: 286 páginas restantes
# 📖 Processando página 47: https://anylogic.help/anylogic/connectivity/internal-database-index.html
# ✅ Página 47: AnyLogic database | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1026 caracteres
#    📚 Fila: 285 páginas restantes
# 📖 Processando página 48: https://anylogic.help/anylogic/connectivity/back-up-database.html
# ✅ Página 48: Back up and restore database | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2440 caracteres
#    📚 Fila: 284 páginas restantes
# 📖 Processando página 49: https://anylogic.help/anylogic/3d/3d-runtime.html
# ✅ Página 49: Moving, rotating, and zooming 3D scene | AnyLogic ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1637 caracteres
#    📚 Fila: 283 páginas restantes
# 📖 Processando página 50: https://anylogic.help/anylogic/3d/import-3d.html
# ✅ Página 50: Importing 3D objects into a model | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2591 caracteres
#    📚 Fila: 282 páginas restantes
# 📖 Processando página 51: https://anylogic.help/anylogic/presentation/ge-layers.html
# ✅ Página 51: Layers | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2059 caracteres
#    📚 Fila: 281 páginas restantes
# 📖 Processando página 52: https://anylogic.help/anylogic/connectivity/view.html
# ✅ Página 52: Database view | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2947 caracteres
#    📚 Fila: 280 páginas restantes
# 📖 Processando página 53: https://anylogic.help/anylogic/system-dynamics/delaymaterial.html
# ✅ Página 53: delayMaterial | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2152 caracteres
#    📚 Fila: 279 páginas restantes
# 📖 Processando página 54: https://anylogic.help/anylogic/gis/gis-search.html
# ✅ Página 54: Finding locations on GIS map | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6900 caracteres
#    📚 Fila: 278 páginas restantes
# 📖 Processando página 55: https://anylogic.help/anylogic/data/collection-variables.html
# ✅ Página 55: Collection | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 13463 caracteres
#    📚 Fila: 277 páginas restantes
# 📖 Processando página 56: https://anylogic.help/anylogic/analysis/scale-types.html
# ✅ Página 56: Scaling charts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3743 caracteres
#    📚 Fila: 276 páginas restantes
# 📖 Processando página 57: https://anylogic.help/anylogic/statecharts/animating.html
# ✅ Página 57: Animating behavior defined by a statechart | AnyLo...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1234 caracteres
#    📚 Fila: 275 páginas restantes
# 📖 Processando página 58: https://anylogic.help/anylogic/statecharts/event-index.html
# ✅ Página 58: Events | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 755 caracteres
#    📚 Fila: 274 páginas restantes
# 📖 Processando página 59: https://anylogic.help/anylogic/experiments/custom-experiment.html
# ✅ Página 59: Custom experiment | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5832 caracteres
#    📚 Fila: 273 páginas restantes
# 📖 Processando página 60: https://anylogic.help/anylogic/data/subset.html
# ✅ Página 60: Select element(s) from a collection | AnyLogic Hel...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3417 caracteres
#    📚 Fila: 272 páginas restantes
# 📖 Processando página 61: https://anylogic.help/anylogic/presentation/rounded-rectangle.html
# ✅ Página 61: Rounded rectangle | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1891 caracteres
#    📚 Fila: 271 páginas restantes
# 📖 Processando página 62: https://anylogic.help/anylogic/analysis/h2d.html
# ✅ Página 62: Histogram 2D data | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3158 caracteres
#    📚 Fila: 270 páginas restantes
# 📖 Processando página 63: https://anylogic.help/anylogic/introduction/activating-dongle.html
# ✅ Página 63: Activating AnyLogic with USB dongle | AnyLogic Hel...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3600 caracteres
#    📚 Fila: 269 páginas restantes
# 📖 Processando página 64: https://anylogic.help/anylogic/agentbased/agent-db.html
# ✅ Página 64: Creating a population based on DB data | AnyLogic ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6277 caracteres
#    📚 Fila: 268 páginas restantes
# 📖 Processando página 65: https://anylogic.help/anylogic/connectivity/db-index.html
# ✅ Página 65: Databases and external data sources | AnyLogic Hel...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 589 caracteres
#    📚 Fila: 267 páginas restantes
# 📖 Processando página 66: https://anylogic.help/anylogic/ui/format-code.html
# ✅ Página 66: Code formatting | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2627 caracteres
#    📚 Fila: 266 páginas restantes
# 📖 Processando página 67: https://anylogic.help/anylogic/data/function.html
# ✅ Página 67: Function | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4500 caracteres
#    📚 Fila: 265 páginas restantes
# 📖 Processando página 68: https://anylogic.help/anylogic/agentbased/movement-gis.html
# ✅ Página 68: Movement in GIS space | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 9161 caracteres
#    📚 Fila: 264 páginas restantes
# 📖 Processando página 69: https://anylogic.help/anylogic/controls/progress-bar.html
# ✅ Página 69: Progress bar | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1721 caracteres
#    📚 Fila: 263 páginas restantes
# 📖 Processando página 70: https://anylogic.help/anylogic/system-dynamics/ramp.html
# ✅ Página 70: ramp | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1188 caracteres
#    📚 Fila: 262 páginas restantes
# 📖 Processando página 71: https://anylogic.help/anylogic/ui/ge-clone.html
# ✅ Página 71: Simultaneous work with several diagrams | AnyLogic...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2967 caracteres
#    📚 Fila: 261 páginas restantes
# 📖 Processando página 72: https://anylogic.help/anylogic/data/collections-api.html
# ✅ Página 72: Working with collection contents | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3507 caracteres
#    📚 Fila: 260 páginas restantes
# 📖 Processando página 73: https://anylogic.help/anylogic/statecharts/index.html
# ✅ Página 73: Statecharts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1191 caracteres
#    📚 Fila: 259 páginas restantes
# 📖 Processando página 74: https://anylogic.help/anylogic/ui/creating-a-new-model.html
# ✅ Página 74: Creating a new model | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2153 caracteres
#    📚 Fila: 258 páginas restantes
# 📖 Processando página 75: https://anylogic.help/anylogic/ui/palette-view.html
# ✅ Página 75: Palette view | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 8940 caracteres
#    📚 Fila: 257 páginas restantes
# 📖 Processando página 76: https://anylogic.help/anylogic/running/control-panel.html
# ✅ Página 76: Control panel | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4519 caracteres
#    📚 Fila: 256 páginas restantes
# 📖 Processando página 77: https://anylogic.help/anylogic/agentbased/agent-population.html
# ✅ Página 77: Agent population properties | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1294 caracteres
#    📚 Fila: 255 páginas restantes
# 📖 Processando página 78: https://anylogic.help/anylogic/data/schedule-tu.html
# ✅ Página 78: Schedule with no calendar mapping | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4708 caracteres
#    📚 Fila: 254 páginas restantes
# 📖 Processando página 79: https://anylogic.help/anylogic/connectivity/text-file.html
# ✅ Página 79: Text file | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3913 caracteres
#    📚 Fila: 253 páginas restantes
# 📖 Processando página 80: https://anylogic.help/anylogic/data/sort-collection.html
# ✅ Página 80: Sorted list of elements within a collection | AnyL...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3124 caracteres
#    📚 Fila: 252 páginas restantes
# 📖 Processando página 81: https://anylogic.help/anylogic/running/export-java-application.html
# ✅ Página 81: Export models to Java applications | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 18401 caracteres
#    📚 Fila: 251 páginas restantes
# 📖 Processando página 82: https://anylogic.help/anylogic/introduction/activation-index.html
# ✅ Página 82: AnyLogic activation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 787 caracteres
#    📚 Fila: 250 páginas restantes
# 📖 Processando página 83: https://anylogic.help/anylogic/analysis/chart-grid-and-labels.html
# ✅ Página 83: Chart grid and labels | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2660 caracteres
#    📚 Fila: 249 páginas restantes
# 📖 Processando página 84: https://anylogic.help/anylogic/experiments/calibration.html
# ✅ Página 84: Calibration | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6018 caracteres
#    📚 Fila: 248 páginas restantes
# 📖 Processando página 85: https://anylogic.help/anylogic/system-dynamics/delay3.html
# ✅ Página 85: delay3 | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1779 caracteres
#    📚 Fila: 247 páginas restantes
# 📖 Processando página 86: https://anylogic.help/anylogic/agentbased/using-agents-process.html
# ✅ Página 86: Using agents in a process flow | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1746 caracteres
#    📚 Fila: 246 páginas restantes
# 📖 Processando página 87: https://anylogic.help/anylogic/system-dynamics/pulse.html
# ✅ Página 87: pulse | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1207 caracteres
#    📚 Fila: 245 páginas restantes
# 📖 Processando página 88: https://anylogic.help/anylogic/analysis/chart-creation-wizard.html
# ✅ Página 88: Chart creation wizard | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3765 caracteres
#    📚 Fila: 244 páginas restantes
# 📖 Processando página 89: https://anylogic.help/anylogic/ui/models.html
# ✅ Página 89: Models | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1164 caracteres
#    📚 Fila: 243 páginas restantes
# 📖 Processando página 90: https://anylogic.help/anylogic/data/collections-statistics-api.html
# ✅ Página 90: Functions to collect statistics on a collection | ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5321 caracteres
#    📚 Fila: 242 páginas restantes
# 📖 Processando página 91: https://anylogic.help/anylogic/ui/pictures-stencil.html
# ✅ Página 91: Pictures palette | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2069 caracteres
#    📚 Fila: 241 páginas restantes
# 📖 Processando página 92: https://anylogic.help/anylogic/ui/sd.html
# ✅ Página 92: System Dynamics modeling | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4397 caracteres
#    📚 Fila: 240 páginas restantes
# 📖 Processando página 93: https://anylogic.help/anylogic/3d/3d-object.html
# ✅ Página 93: 3D object | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3753 caracteres
#    📚 Fila: 239 páginas restantes
# 📖 Processando página 94: https://anylogic.help/anylogic/ui/zooming-the-diagram.html
# ✅ Página 94: Moving and zooming the diagram UI | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2300 caracteres
#    📚 Fila: 238 páginas restantes
# 📖 Processando página 95: https://anylogic.help/anylogic/stochastic/choose-pdf.html
# ✅ Página 95: Choose Probability Distribution wizard | AnyLogic ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1781 caracteres
#    📚 Fila: 237 páginas restantes
# 📖 Processando página 96: https://anylogic.help/anylogic/presentation/creating-navigation-bar.html
# ✅ Página 96: Creating a navigation bar | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 938 caracteres
#    📚 Fila: 236 páginas restantes
# 📖 Processando página 97: https://anylogic.help/anylogic/gis/agents-placement.html
# ✅ Página 97: Placing agents in GIS space | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4938 caracteres
#    📚 Fila: 235 páginas restantes
# 📖 Processando página 98: https://anylogic.help/anylogic/gis/gis-offline.html
# ✅ Página 98: Taking GIS models offline | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1179 caracteres
#    📚 Fila: 234 páginas restantes
# 📖 Processando página 99: https://anylogic.help/anylogic/system-dynamics/link.html
# ✅ Página 99: Link | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6404 caracteres
#    📚 Fila: 233 páginas restantes
# 📖 Processando página 100: https://anylogic.help/anylogic/agentbased/sort-population.html
# ✅ Página 100: Sorted list of agents within a population | AnyLog...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2487 caracteres
#    📚 Fila: 232 páginas restantes
# 📖 Processando página 101: https://anylogic.help/anylogic/gis/converting-shapefiles.html
# ✅ Página 101: Converting GIS shapefiles to space markup shapes |...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3909 caracteres
#    📚 Fila: 231 páginas restantes
# 📖 Processando página 102: https://anylogic.help/anylogic/ui/keyboard-shortcuts.html
# ✅ Página 102: Keyboard and mouse shortcuts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4955 caracteres
#    📚 Fila: 230 páginas restantes
# 📖 Processando página 103: https://anylogic.help/anylogic/ui/saving-models.html
# ✅ Página 103: Saving models | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1396 caracteres
#    📚 Fila: 229 páginas restantes
# 📖 Processando página 104: https://anylogic.help/anylogic/controls/combo-box.html
# ✅ Página 104: Combo box | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2706 caracteres
#    📚 Fila: 228 páginas restantes
# 📖 Processando página 105: https://anylogic.help/anylogic/3d/far-clipping-distance.html
# ✅ Página 105: Clipping 3D scene | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2126 caracteres
#    📚 Fila: 227 páginas restantes
# 📖 Processando página 106: https://anylogic.help/anylogic/agentbased/building-hierarchical-models.html
# ✅ Página 106: Hierarchical models | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5088 caracteres
#    📚 Fila: 226 páginas restantes
# 📖 Processando página 107: https://anylogic.help/anylogic/ui/modifiers.html
# ✅ Página 107: Icon modifiers | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1712 caracteres
#    📚 Fila: 225 páginas restantes
# 📖 Processando página 108: https://anylogic.help/anylogic/3d/painting.html
# ✅ Página 108: Painting standard and imported 3D objects | AnyLog...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1065 caracteres
#    📚 Fila: 224 páginas restantes
# 📖 Processando página 109: https://anylogic.help/anylogic/gis/index.html
# ✅ Página 109: GIS models | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3059 caracteres
#    📚 Fila: 223 páginas restantes
# 📖 Processando página 110: https://anylogic.help/anylogic/data/dynamic-parameters.html
# ✅ Página 110: Dynamic parameters | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1503 caracteres
#    📚 Fila: 222 páginas restantes
# 📖 Processando página 111: https://anylogic.help/anylogic/presentation/oval.html
# ✅ Página 111: Oval | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2354 caracteres
#    📚 Fila: 221 páginas restantes
# 📖 Processando página 112: https://anylogic.help/anylogic/system-dynamics/smooth3.html
# ✅ Página 112: smooth3 | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1741 caracteres
#    📚 Fila: 220 páginas restantes
# 📖 Processando página 113: https://anylogic.help/anylogic/experiments/customizing-presentation-appearance.html
# ✅ Página 113: Customizing model window | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2715 caracteres
#    📚 Fila: 219 páginas restantes
# 📖 Processando página 114: https://anylogic.help/anylogic/data/schedule-api.html
# ✅ Página 114: Schedule API | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2238 caracteres
#    📚 Fila: 218 páginas restantes
# 📖 Processando página 115: https://anylogic.help/anylogic/controls/button.html
# ✅ Página 115: Button | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1658 caracteres
#    📚 Fila: 217 páginas restantes
# 📖 Processando página 116: https://anylogic.help/anylogic/analysis/bar-chart.html
# ✅ Página 116: Bar chart | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3076 caracteres
#    📚 Fila: 216 páginas restantes
# 📖 Processando página 117: https://anylogic.help/anylogic/troubleshooting/troubleshooting.html
# ✅ Página 117: Troubleshooting | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2568 caracteres
#    📚 Fila: 215 páginas restantes
# 📖 Processando página 118: https://anylogic.help/anylogic/system-dynamics/hierarchical-sd.html
# ✅ Página 118: Hierarchical SD modeling | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4359 caracteres
#    📚 Fila: 214 páginas restantes
# 📖 Processando página 119: https://anylogic.help/anylogic/data/viewing.html
# ✅ Página 119: Viewing values and charts of variables at runtime ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 7351 caracteres
#    📚 Fila: 213 páginas restantes
# 📖 Processando página 120: https://anylogic.help/anylogic/data/setting-up-actual-parameter-values.html
# ✅ Página 120: Altering parameters of embedded agents | AnyLogic ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2041 caracteres
#    📚 Fila: 212 páginas restantes
# 📖 Processando página 121: https://anylogic.help/anylogic/presentation/agent-presentation.html
# ✅ Página 121: Agent presentation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6799 caracteres
#    📚 Fila: 211 páginas restantes
# 📖 Processando página 122: https://anylogic.help/anylogic/analysis/histogram.html
# ✅ Página 122: Histogram | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3764 caracteres
#    📚 Fila: 210 páginas restantes
# 📖 Processando página 123: https://anylogic.help/anylogic/agentbased/agent.html
# ✅ Página 123: Agent | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3824 caracteres
#    📚 Fila: 209 páginas restantes
# 📖 Processando página 124: https://anylogic.help/anylogic/system-dynamics/index.html
# ✅ Página 124: System dynamics | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4504 caracteres
#    📚 Fila: 208 páginas restantes
# 📖 Processando página 125: https://anylogic.help/anylogic/analysis/chart-area.html
# ✅ Página 125: Chart area | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2703 caracteres
#    📚 Fila: 207 páginas restantes
# 📖 Processando página 126: https://anylogic.help/anylogic/ui/anylogic-palettes.html
# ✅ Página 126: AnyLogic palettes | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6492 caracteres
#    📚 Fila: 206 páginas restantes
# 📖 Processando página 127: https://anylogic.help/anylogic/ui/autosave.html
# ✅ Página 127: Automatic backup and recovery of models | AnyLogic...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2668 caracteres
#    📚 Fila: 205 páginas restantes
# 📖 Processando página 128: https://anylogic.help/anylogic/agentbased/index.html
# ✅ Página 128: Agent-based modeling | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 10026 caracteres
#    📚 Fila: 204 páginas restantes
# 📖 Processando página 129: https://anylogic.help/anylogic/presentation/presentation-shapes.html
# ✅ Página 129: Presentation shapes | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1180 caracteres
#    📚 Fila: 203 páginas restantes
# 📖 Processando página 130: https://anylogic.help/anylogic/statecharts/statecharts-api.html
# ✅ Página 130: Statechart functions | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1141 caracteres
#    📚 Fila: 202 páginas restantes
# 📖 Processando página 131: https://anylogic.help/anylogic/introduction/activation-with-permanent-key.html
# ✅ Página 131: Activating AnyLogic with the key | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5565 caracteres
#    📚 Fila: 201 páginas restantes
# 📖 Processando página 132: https://anylogic.help/anylogic/ui/refactoring.html
# ✅ Página 132: Renaming model elements | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2948 caracteres
#    📚 Fila: 200 páginas restantes
# 📖 Processando página 133: https://anylogic.help/anylogic/statecharts/highlighting-statechart-activities.html
# ✅ Página 133: Highlighting statechart activities | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1730 caracteres
#    📚 Fila: 199 páginas restantes
# 📖 Processando página 134: https://anylogic.help/anylogic/agentbased/creating-agent.html
# ✅ Página 134: Creating a population of agents | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5218 caracteres
#    📚 Fila: 198 páginas restantes
# 📖 Processando página 135: https://anylogic.help/anylogic/presentation/polyline.html
# ✅ Página 135: Polyline | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4641 caracteres
#    📚 Fila: 197 páginas restantes
# 📖 Processando página 136: https://anylogic.help/anylogic/agentbased/agent-speed.html
# ✅ Página 136: Agent movement speed | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4198 caracteres
#    📚 Fila: 196 páginas restantes
# 📖 Processando página 137: https://anylogic.help/anylogic/data/generic-parameters.html
# ✅ Página 137: Generic parameters | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3902 caracteres
#    📚 Fila: 195 páginas restantes
# 📖 Processando página 138: https://anylogic.help/anylogic/statecharts/statechart-entry-point.html
# ✅ Página 138: Statechart entry point | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2329 caracteres
#    📚 Fila: 194 páginas restantes
# 📖 Processando página 139: https://anylogic.help/anylogic/statecharts/statechart-rules.html
# ✅ Página 139: Statechart declaration rules | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2005 caracteres
#    📚 Fila: 193 páginas restantes
# 📖 Processando página 140: https://anylogic.help/anylogic/3d/index.html
# ✅ Página 140: 3D animation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2235 caracteres
#    📚 Fila: 192 páginas restantes
# 📖 Processando página 141: https://anylogic.help/anylogic/experiments/numerical-solvers.html
# ✅ Página 141: Numerical solvers for SD | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2390 caracteres
#    📚 Fila: 191 páginas restantes
# 📖 Processando página 142: https://anylogic.help/anylogic/presentation/arc.html
# ✅ Página 142: Arc | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4181 caracteres
#    📚 Fila: 190 páginas restantes
# 📖 Processando página 143: https://anylogic.help/anylogic/analysis/updating-data-sets.html
# ✅ Página 143: Updating data sets | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3522 caracteres
#    📚 Fila: 189 páginas restantes
# 📖 Processando página 144: https://anylogic.help/anylogic/connectivity/db-api.html
# ✅ Página 144: Database API | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2932 caracteres
#    📚 Fila: 188 páginas restantes
# 📖 Processando página 145: https://anylogic.help/anylogic/experiments/index.html
# ✅ Página 145: Experiments framework | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 675 caracteres
#    📚 Fila: 187 páginas restantes
# 📖 Processando página 146: https://anylogic.help/anylogic/experiments/compare-runs-experiment.html
# ✅ Página 146: Compare runs | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4812 caracteres
#    📚 Fila: 186 páginas restantes
# 📖 Processando página 147: https://anylogic.help/anylogic/connectivity/agent-db.html
# ✅ Página 147: Creating a population based on DB data | AnyLogic ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6383 caracteres
#    📚 Fila: 185 páginas restantes
# 📖 Processando página 148: https://anylogic.help/anylogic/connectivity/data-types.html
# ✅ Página 148: AnyLogic DB data types | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2947 caracteres
#    📚 Fila: 184 páginas restantes
# 📖 Processando página 149: https://anylogic.help/anylogic/ui/editions.html
# ✅ Página 149: AnyLogic editions comparison | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3837 caracteres
#    📚 Fila: 183 páginas restantes
# 📖 Processando página 150: https://anylogic.help/anylogic/agentbased/movement-continuous.html
# ✅ Página 150: Movement in continuous space | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 7796 caracteres
#    📚 Fila: 182 páginas restantes
# 📖 Processando página 151: https://anylogic.help/anylogic/analysis/charts.html
# ✅ Página 151: Charts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2281 caracteres
#    📚 Fila: 181 páginas restantes
# 📖 Processando página 152: https://anylogic.help/anylogic/analysis/data-set.html
# ✅ Página 152: Data set | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3377 caracteres
#    📚 Fila: 180 páginas restantes
# 📖 Processando página 153: https://anylogic.help/anylogic/ui/ge-layers.html
# ✅ Página 153: Layers | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2419 caracteres
#    📚 Fila: 179 páginas restantes
# 📖 Processando página 154: https://anylogic.help/anylogic/ui/relative-filepaths.html
# ✅ Página 154: Using relative and absolute paths | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2024 caracteres
#    📚 Fila: 178 páginas restantes
# 📖 Processando página 155: https://anylogic.help/anylogic/gis/gis-defining-routes.html
# ✅ Página 155: Defining routes on GIS map | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 11292 caracteres
#    📚 Fila: 177 páginas restantes
# 📖 Processando página 156: https://anylogic.help/anylogic/running/run-simulation.html
# ✅ Página 156: Running a model | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2472 caracteres
#    📚 Fila: 176 páginas restantes
# 📖 Processando página 157: https://anylogic.help/anylogic/running/snapshots.html
# ✅ Página 157: Saving and restoring the model snapshot | AnyLogic...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 20757 caracteres
#    📚 Fila: 175 páginas restantes
# 📖 Processando página 158: https://anylogic.help/anylogic/agentbased/statistics.html
# ✅ Página 158: Collecting statistics on agents | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5482 caracteres
#    📚 Fila: 174 páginas restantes
# 📖 Processando página 159: https://anylogic.help/anylogic/presentation/cad.html
# ✅ Página 159: CAD drawing | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4276 caracteres
#    📚 Fila: 173 páginas restantes
# 📖 Processando página 160: https://anylogic.help/anylogic/connectivity/resources.html
# ✅ Página 160: File resources | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4174 caracteres
#    📚 Fila: 172 páginas restantes
# 📖 Processando página 161: https://anylogic.help/anylogic/ui/console-view.html
# ✅ Página 161: Console view | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2008 caracteres
#    📚 Fila: 171 páginas restantes
# 📖 Processando página 162: https://anylogic.help/anylogic/analysis/output.html
# ✅ Página 162: Output | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4337 caracteres
#    📚 Fila: 170 páginas restantes
# 📖 Processando página 163: https://anylogic.help/anylogic/system-dynamics/arrays.html
# ✅ Página 163: Arrays | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 16474 caracteres
#    📚 Fila: 169 páginas restantes
# 📖 Processando página 164: https://anylogic.help/anylogic/experiments/optimization.html
# ✅ Página 164: Optimization | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 25666 caracteres
#    📚 Fila: 168 páginas restantes
# 📖 Processando página 165: https://anylogic.help/anylogic/analysis/viewing-data.html
# ✅ Página 165: Viewing and copying collected data | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1206 caracteres
#    📚 Fila: 167 páginas restantes
# 📖 Processando página 166: https://anylogic.help/anylogic/connectivity/anylogic-connectivity-tools.html
# ✅ Página 166: External database | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1529 caracteres
#    📚 Fila: 166 páginas restantes
# 📖 Processando página 167: https://anylogic.help/anylogic/presentation/active-object-icon.html
# ✅ Página 167: Icon | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3941 caracteres
#    📚 Fila: 165 páginas restantes
# 📖 Processando página 168: https://anylogic.help/anylogic/data/altering-parameters-of-experiment's-main-object.html
# ✅ Página 168: Altering parameters of top-level agent | AnyLogic ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1509 caracteres
#    📚 Fila: 164 páginas restantes
# 📖 Processando página 169: https://anylogic.help/anylogic/analysis/statistics.html
# ✅ Página 169: Statistics | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4115 caracteres
#    📚 Fila: 163 páginas restantes
# 📖 Processando página 170: https://anylogic.help/anylogic/3d/light3d.html
# ✅ Página 170: Light | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6083 caracteres
#    📚 Fila: 162 páginas restantes
# 📖 Processando página 171: https://anylogic.help/anylogic/ui/closing-a-model.html
# ✅ Página 171: Closing models | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1633 caracteres
#    📚 Fila: 161 páginas restantes
# 📖 Processando página 172: https://anylogic.help/anylogic/system-dynamics/step.html
# ✅ Página 172: step | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1488 caracteres
#    📚 Fila: 160 páginas restantes
# 📖 Processando página 173: https://anylogic.help/anylogic/stochastic/reproducible.html
# ✅ Página 173: Reproducible model runs | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5019 caracteres
#    📚 Fila: 159 páginas restantes
# 📖 Processando página 174: https://anylogic.help/anylogic/stochastic/selecting-random.html
# ✅ Página 174: How to select a random... | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 8320 caracteres
#    📚 Fila: 158 páginas restantes
# 📖 Processando página 175: https://anylogic.help/anylogic/agentbased/movement-network.html
# ✅ Página 175: Agents movement inside and outside network | AnyLo...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2608 caracteres
#    📚 Fila: 157 páginas restantes
# 📖 Processando página 176: https://anylogic.help/anylogic/statecharts/dynamic-event.html
# ✅ Página 176: Dynamic event | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6446 caracteres
#    📚 Fila: 156 páginas restantes
# 📖 Processando página 177: https://anylogic.help/anylogic/data/schedule-preview.html
# ✅ Página 177: Schedule preview | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1758 caracteres
#    📚 Fila: 155 páginas restantes
# 📖 Processando página 178: https://anylogic.help/anylogic/controls/experiment-controls.html
# ✅ Página 178: Setting up parameters prior to model execution | A...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3191 caracteres
#    📚 Fila: 154 páginas restantes
# 📖 Processando página 179: https://anylogic.help/anylogic/analysis/histogram-2d.html
# ✅ Página 179: Histogram 2D | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3162 caracteres
#    📚 Fila: 153 páginas restantes
# 📖 Processando página 180: https://anylogic.help/anylogic/running/developer-panel.html
# ✅ Página 180: Developer panel | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 7724 caracteres
#    📚 Fila: 152 páginas restantes
# 📖 Processando página 181: https://anylogic.help/anylogic/ui/anylogic-toolbars.html
# ✅ Página 181: AnyLogic toolbars | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5278 caracteres
#    📚 Fila: 151 páginas restantes
# 📖 Processando página 182: https://anylogic.help/anylogic/experiments/sensitivity-analysis-experiment.html
# ✅ Página 182: Sensitivity analysis | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3732 caracteres
#    📚 Fila: 150 páginas restantes
# 📖 Processando página 183: https://anylogic.help/anylogic/statecharts/history-state.html
# ✅ Página 183: History state | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3078 caracteres
#    📚 Fila: 149 páginas restantes
# 📖 Processando página 184: https://anylogic.help/anylogic/agentbased/synchronization.html
# ✅ Página 184: Agent synchronization | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4392 caracteres
#    📚 Fila: 148 páginas restantes
# 📖 Processando página 185: https://anylogic.help/anylogic/ui/working-with-views.html
# ✅ Página 185: Working with views | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4444 caracteres
#    📚 Fila: 147 páginas restantes
# 📖 Processando página 186: https://anylogic.help/anylogic/running/index.html
# ✅ Página 186: Running a model | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 925 caracteres
#    📚 Fila: 146 páginas restantes
# 📖 Processando página 187: https://anylogic.help/anylogic/analysis/index.html
# ✅ Página 187: Data analysis items | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 703 caracteres
#    📚 Fila: 145 páginas restantes
# 📖 Processando página 188: https://anylogic.help/anylogic/analysis/charts-index.html
# ✅ Página 188: Visualizing data using charts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 919 caracteres
#    📚 Fila: 144 páginas restantes
# 📖 Processando página 189: https://anylogic.help/anylogic/ui/perspectives.html
# ✅ Página 189: Perspectives | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2162 caracteres
#    📚 Fila: 143 páginas restantes
# 📖 Processando página 190: https://anylogic.help/anylogic/presentation/curve.html
# ✅ Página 190: Curve | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6118 caracteres
#    📚 Fila: 142 páginas restantes
# 📖 Processando página 191: https://anylogic.help/anylogic/experiments/simulation-experiment.html
# ✅ Página 191: Simulation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1684 caracteres
#    📚 Fila: 141 páginas restantes
# 📖 Processando página 192: https://anylogic.help/anylogic/introduction/activation-tls.html
# ✅ Página 192: Activating AnyLogic with Team License Server | Any...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2733 caracteres
#    📚 Fila: 140 páginas restantes
# 📖 Processando página 193: https://anylogic.help/anylogic/ui/ge-axis.html
# ✅ Página 193: Visible area and coordinates | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3033 caracteres
#    📚 Fila: 139 páginas restantes
# 📖 Processando página 194: https://anylogic.help/anylogic/agentbased/movement-discrete.html
# ✅ Página 194: Movement in discrete space | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4122 caracteres
#    📚 Fila: 138 páginas restantes
# 📖 Processando página 195: https://anylogic.help/anylogic/introduction/release-notes.html
# ✅ Página 195: Release notes | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 145220 caracteres
#    📚 Fila: 137 páginas restantes
# 📖 Processando página 196: https://anylogic.help/anylogic/statecharts/events.html
# ✅ Página 196: Event | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 15229 caracteres
#    📚 Fila: 136 páginas restantes
# 📖 Processando página 197: https://anylogic.help/anylogic/presentation/canvas.html
# ✅ Página 197: Canvas | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3196 caracteres
#    📚 Fila: 135 páginas restantes
# 📖 Processando página 198: https://anylogic.help/anylogic/ui/problems-view.html
# ✅ Página 198: Problems view | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3426 caracteres
#    📚 Fila: 134 páginas restantes
# 📖 Processando página 199: https://anylogic.help/anylogic/agentbased/dynamic-creation-and-destruction.html
# ...
# ✅ Página 276: trend | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1354 caracteres
#    📚 Fila: 56 páginas restantes
# 📖 Processando página 277: https://anylogic.help/anylogic/introduction/anylogic-professional.html
# ✅ Página 277: AnyLogic Professional | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5249 caracteres
#    📚 Fila: 55 páginas restantes
# 📖 Processando página 278: https://anylogic.help/anylogic/connectivity/queries-index.html
# ✅ Página 278: Writing queries | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1055 caracteres
#    📚 Fila: 54 páginas restantes
# 📖 Processando página 279: https://anylogic.help/anylogic/statecharts/event-processing.html
# ✅ Página 279: Events in simulation engine | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4832 caracteres
#    📚 Fila: 53 páginas restantes
# 📖 Processando página 280: https://anylogic.help/anylogic/agentbased/communication.html
# ✅ Página 280: Communication between agents | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5099 caracteres
#    📚 Fila: 52 páginas restantes
# 📖 Processando página 281: https://anylogic.help/anylogic/ui/concepts-index.html
# ✅ Página 281: Basic concepts | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 419 caracteres
#    📚 Fila: 51 páginas restantes
# 📖 Processando página 282: https://anylogic.help/anylogic/running/engine-api.html
# ✅ Página 282: Engine API | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1240 caracteres
#    📚 Fila: 50 páginas restantes
# 📖 Processando página 283: https://anylogic.help/anylogic/stochastic/custom-distribution.html
# ✅ Página 283: Custom distribution | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5558 caracteres
#    📚 Fila: 49 páginas restantes
# 📖 Processando página 284: https://anylogic.help/anylogic/statecharts/execution-order.html
# ✅ Página 284: Execution order. Example | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2951 caracteres
#    📚 Fila: 48 páginas restantes
# 📖 Processando página 285: https://anylogic.help/anylogic/connectivity/use-cases-index.html
# ✅ Página 285: Use cases | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1245 caracteres
#    📚 Fila: 47 páginas restantes
# 📖 Processando página 286: https://anylogic.help/anylogic/running/enhanced-execution-control.html
# ✅ Página 286: Running the model for a certain time period | AnyL...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3703 caracteres
#    📚 Fila: 46 páginas restantes
# 📖 Processando página 287: https://anylogic.help/anylogic/analysis/plot.html
# ✅ Página 287: Plot | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3766 caracteres
#    📚 Fila: 45 páginas restantes
# 📖 Processando página 288: https://anylogic.help/anylogic/ui/projects-view.html
# ✅ Página 288: Projects view | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5663 caracteres
#    📚 Fila: 44 páginas restantes
# 📖 Processando página 289: https://anylogic.help/anylogic/introduction/style-conventions.html
# ✅ Página 289: Style conventions | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3744 caracteres
#    📚 Fila: 43 páginas restantes
# 📖 Processando página 290: https://anylogic.help/anylogic/agentbased/inspecting-agents.html
# ✅ Página 290: Inspecting agents | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3266 caracteres
#    📚 Fila: 42 páginas restantes
# 📖 Processando página 291: https://anylogic.help/anylogic/presentation/text.html
# ✅ Página 291: Text | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2278 caracteres
#    📚 Fila: 41 páginas restantes
# 📖 Processando página 292: https://anylogic.help/anylogic/analysis/stack-chart.html
# ✅ Página 292: Stack chart | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3394 caracteres
#    📚 Fila: 40 páginas restantes
# 📖 Processando página 293: https://anylogic.help/anylogic/data/schedule-calendar.html
# ✅ Página 293: Calendar schedule | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6718 caracteres
#    📚 Fila: 39 páginas restantes
# 📖 Processando página 294: https://anylogic.help/anylogic/gis/gis-scaling-agents.html
# ✅ Página 294: Scaling agent animations on GIS map | AnyLogic Hel...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3620 caracteres
#    📚 Fila: 38 páginas restantes
# 📖 Processando página 295: https://anylogic.help/anylogic/ui/model-formats.html
# ✅ Página 295: Model file formats | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3121 caracteres
#    📚 Fila: 37 páginas restantes
# 📖 Processando página 296: https://anylogic.help/anylogic/system-dynamics/npve.html
# ✅ Página 296: npve | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1465 caracteres
#    📚 Fila: 36 páginas restantes
# 📖 Processando página 297: https://anylogic.help/anylogic/connectivity/creating-table.html
# ✅ Página 297: Creating database tables | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3092 caracteres
#    📚 Fila: 35 páginas restantes
# 📖 Processando página 298: https://anylogic.help/anylogic/connectivity/database.html
# ✅ Página 298: AnyLogic database | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2546 caracteres
#    📚 Fila: 34 páginas restantes
# 📖 Processando página 299: https://anylogic.help/anylogic/presentation/animating-replicated-objects.html
# ✅ Página 299: Animating replicated objects | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1876 caracteres
#    📚 Fila: 33 páginas restantes
# 📖 Processando página 300: https://anylogic.help/anylogic/controls/file-chooser.html
# ✅ Página 300: File chooser | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2772 caracteres
#    📚 Fila: 32 páginas restantes
# 📖 Processando página 301: https://anylogic.help/anylogic/statecharts/transition.html
# ✅ Página 301: Transition | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 18479 caracteres
#    📚 Fila: 31 páginas restantes
# 📖 Processando página 302: https://anylogic.help/anylogic/presentation/index.html
# ✅ Página 302: 2D and 3D animation | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2852 caracteres
#    📚 Fila: 30 páginas restantes
# 📖 Processando página 303: https://anylogic.help/anylogic/controls/linking.html
# ✅ Página 303: Linking controls to parameters | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2582 caracteres
#    📚 Fila: 29 páginas restantes
# 📖 Processando página 304: https://anylogic.help/anylogic/gis/route-provider.html
# ✅ Página 304: Alternative route providers for cars and trains | ...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3504 caracteres
#    📚 Fila: 28 páginas restantes
# 📖 Processando página 305: https://anylogic.help/anylogic/system-dynamics/flow.html
# ✅ Página 305: Flow | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 5939 caracteres
#    📚 Fila: 27 páginas restantes
# 📖 Processando página 306: https://anylogic.help/anylogic/analysis/time-stack-chart.html
# ✅ Página 306: Time stack chart | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4038 caracteres
#    📚 Fila: 26 páginas restantes
# 📖 Processando página 307: https://anylogic.help/anylogic/ui/support-services.html
# ✅ Página 307: AnyLogic support services | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 7967 caracteres
#    📚 Fila: 25 páginas restantes
# 📖 Processando página 308: https://anylogic.help/anylogic/ui/approaches-index.html
# ✅ Página 308: Modeling approaches | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 693 caracteres
#    📚 Fila: 24 páginas restantes
# 📖 Processando página 309: https://anylogic.help/anylogic/troubleshooting/howto.html
# ✅ Página 309: How to... | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4764 caracteres
#    📚 Fila: 23 páginas restantes
# 📖 Processando página 310: https://anylogic.help/anylogic/agentbased/link.html
# ✅ Página 310: Link to agents: custom agent connections | AnyLogi...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4008 caracteres
#    📚 Fila: 22 páginas restantes
# 📖 Processando página 311: https://anylogic.help/anylogic/experiments/rl-experiment.html
# ✅ Página 311: Reinforcement Learning | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 9257 caracteres
#    📚 Fila: 21 páginas restantes
# 📖 Processando página 312: https://anylogic.help/anylogic/presentation/group.html
# ✅ Página 312: Group | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4235 caracteres
#    📚 Fila: 20 páginas restantes
# 📖 Processando página 313: https://anylogic.help/anylogic/experiments/about-experiments.html
# ✅ Página 313: Experiments | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3787 caracteres
#    📚 Fila: 19 páginas restantes
# 📖 Processando página 314: https://anylogic.help/anylogic/ui/anylogic-statusbar.html
# ✅ Página 314: AnyLogic status bar | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3167 caracteres
#    📚 Fila: 18 páginas restantes
# 📖 Processando página 315: https://anylogic.help/anylogic/ui/system-requirements.html
# ✅ Página 315: System requirements | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2603 caracteres
#    📚 Fila: 17 páginas restantes
# 📖 Processando página 316: https://anylogic.help/anylogic/ui/working-with-shapes-and-elements.html
# ✅ Página 316: Working with shapes and elements | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6050 caracteres
#    📚 Fila: 16 páginas restantes
# 📖 Processando página 317: https://anylogic.help/anylogic/ui/multimethod.html
# ✅ Página 317: Multimethod modeling | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3551 caracteres
#    📚 Fila: 15 páginas restantes
# 📖 Processando página 318: https://anylogic.help/anylogic/running/initialization-order.html
# ✅ Página 318: Model execution order | AnyLogic Help...
#    📊 Links encontrados: 333 | Novos: 1
#    📏 Conteúdo: 4976 caracteres
#    📚 Fila: 15 páginas restantes
# 📖 Processando página 319: https://anylogic.help/anylogic/connectivity/selectquery.html
# ✅ Página 319: SelectQuery API | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1245 caracteres
#    📚 Fila: 14 páginas restantes
# 📖 Processando página 320: https://anylogic.help/anylogic/system-dynamics/shadow-variables.html
# ✅ Página 320: Shadow | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3955 caracteres
#    📚 Fila: 13 páginas restantes
# 📖 Processando página 321: https://anylogic.help/anylogic/ui/undo-and-redo.html
# ✅ Página 321: Undo and redo | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1593 caracteres
#    📚 Fila: 12 páginas restantes
# 📖 Processando página 322: https://anylogic.help/anylogic/troubleshooting/index.html
# ✅ Página 322: FAQ | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 417 caracteres
#    📚 Fila: 11 páginas restantes
# 📖 Processando página 323: https://anylogic.help/anylogic/data/parameters-index.html
# ✅ Página 323: Parameters | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 913 caracteres
#    📚 Fila: 10 páginas restantes
# 📖 Processando página 324: https://anylogic.help/anylogic/data/schedule-week.html
# ✅ Página 324: Weekly schedule | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 7929 caracteres
#    📚 Fila: 9 páginas restantes
# 📖 Processando página 325: https://anylogic.help/anylogic/ui/menu.html
# ✅ Página 325: AnyLogic menu | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 12321 caracteres
#    📚 Fila: 8 páginas restantes
# 📖 Processando página 326: https://anylogic.help/anylogic/ui/managing-a-model.html
# ✅ Página 326: Managing model elements | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 1793 caracteres
#    📚 Fila: 7 páginas restantes
# 📖 Processando página 327: https://anylogic.help/anylogic/agentbased/subset.html
# ✅ Página 327: Select an agent or agents from a population | AnyL...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 3529 caracteres
#    📚 Fila: 6 páginas restantes
# 📖 Processando página 328: https://anylogic.help/anylogic/statecharts/checking-active-state.html
# ✅ Página 328: Checking the agent’s state | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 4222 caracteres
#    📚 Fila: 5 páginas restantes
# 📖 Processando página 329: https://anylogic.help/anylogic/controls/replicated-control.html
# ✅ Página 329: Replicated controls | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2986 caracteres
#    📚 Fila: 4 páginas restantes
# 📖 Processando página 330: https://anylogic.help/anylogic/system-dynamics/vensim-import.html
# ✅ Página 330: Importing Vensim® models | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 6250 caracteres
#    📚 Fila: 3 páginas restantes
# 📖 Processando página 331: https://anylogic.help/anylogic/statecharts/branch.html
# ✅ Página 331: Branch | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2696 caracteres
#    📚 Fila: 2 páginas restantes
# 📖 Processando página 332: https://anylogic.help/anylogic/agentbased/inheritance.html
# ✅ Página 332: Agent inheritance | AnyLogic Help...
#    📊 Links encontrados: 332 | Novos: 0
#    📏 Conteúdo: 2604 caracteres
#    📚 Fila: 1 páginas restantes
# 📖 Processando página 333: https://anylogic.help/anylogic/running/images/initialization-order.png
# ✅ Página 333: initialization-order.png (2287×1806)...
#    📊 Links encontrados: 0 | Novos: 0
#    📏 Conteúdo: 0 caracteres
#    📚 Fila: 0 páginas restantes
#
# 🎯 Crawling completo! 333 páginas processadas.
# 📄 Criando arquivo consolidado: anylogic_documentacao_completa.txt
# 📝 Escrita: 10/333 páginas...
# 📝 Escrita: 20/333 páginas...
# 📝 Escrita: 30/333 páginas...
# 📝 Escrita: 40/333 páginas...
# 📝 Escrita: 50/333 páginas...
# 📝 Escrita: 60/333 páginas...
# 📝 Escrita: 70/333 páginas...
# 📝 Escrita: 80/333 páginas...
# 📝 Escrita: 90/333 páginas...
# 📝 Escrita: 100/333 páginas...
# 📝 Escrita: 110/333 páginas...
# 📝 Escrita: 120/333 páginas...
# 📝 Escrita: 130/333 páginas...
# 📝 Escrita: 140/333 páginas...
# 📝 Escrita: 150/333 páginas...
# 📝 Escrita: 160/333 páginas...
# 📝 Escrita: 170/333 páginas...
# 📝 Escrita: 180/333 páginas...
# 📝 Escrita: 190/333 páginas...
# 📝 Escrita: 200/333 páginas...
# 📝 Escrita: 210/333 páginas...
# 📝 Escrita: 220/333 páginas...
# 📝 Escrita: 230/333 páginas...
# 📝 Escrita: 240/333 páginas...
# 📝 Escrita: 250/333 páginas...
# 📝 Escrita: 260/333 páginas...
# 📝 Escrita: 270/333 páginas...
# 📝 Escrita: 280/333 páginas...
# 📝 Escrita: 290/333 páginas...
# 📝 Escrita: 300/333 páginas...
# 📝 Escrita: 310/333 páginas...
# 📝 Escrita: 320/333 páginas...
# 📝 Escrita: 330/333 páginas...
# ✅ Arquivo consolidado criado: anylogic_documentacao_completa.txt
# ✅ 333 páginas individuais salvas em 'anylogic_pages/'
#
# 📊 ESTATÍSTICAS DA DOCUMENTAÇÃO:
#    📚 Total de páginas: 333
#    📏 Total de caracteres: 1,501,697
#    🔤 Total de palavras: 237,770
#    📄 Média por página: 4,509 caracteres
#    🌐 URLs únicas coletadas: 333
#
# 🏆 TOP 10 PÁGINAS COM MAIS CONTEÚDO:
#     1. Release notes | AnyLogic Help... (145,220 chars)
#     2. Optimization | AnyLogic Help... (25,666 chars)
#     3. Saving and restoring the model snapshot | AnyLogic... (20,757 chars)
#     4. Transition | AnyLogic Help... (18,479 chars)
#     5. Export models to Java applications | AnyLogic Help... (18,401 chars)
#     6. AnyLogic preferences | AnyLogic Help... (17,537 chars)
#     7. Arrays | AnyLogic Help... (16,474 chars)
#     8. Writing database queries | AnyLogic Help... (15,801 chars)
#     9. Editing presentation shapes | AnyLogic Help... (15,780 chars)
#    10. Event | AnyLogic Help... (15,229 chars)
#
# 💾 DOCUMENTAÇÃO SALVA COM SUCESSO!
# 📁 Arquivo principal: anylogic_documentacao_completa.txt
# ⏱️  Tempo total: 3753.71 segundos
# 📦 Tamanho aproximado: 1.53 MB
